# %% [markdown]
# # Inferential Statistics
# Goalsnya untuk -> mengira rata2 dari sesuatu
#                -> seberapa yakin kita dgn rata2 kita

# %%
# import lib
import numpy as np
# %matplotlib inline
import matplotlib as plt
from IPython.display import Math, Latex
from IPython.core.display import Image

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

# %%
from scipy.stats import uniform

# %%
# mencari peluang
# distribusi uniform-> param nilai rata2
n = 10000
start = 10
width = 20
uniform_data = uniform.rvs(size=n, loc=start, scale=width)

# %%
# hasil diplot
ax = sns.distplot(uniform_data, 
                 bins = 100,
                 kde = True,
                 color = 'skyblue',
                 hist_kws = {'linewidth':15, 'alpha':1})
ax.set(xlabel='Uniform Distribution', ylabel='Frequency')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Uniform Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# distribusi normal -> param std(scale), dan M
std = norm.rvs(loc=0, scale=1, size= 1000000)
ax = sns.distplot(std, 
                 bins=100,
                 kde=True,
                 color='skyblue',
                 hist_kws={'linewidth': 15, 'alpha': 1})
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import norm

# %%
data_normal = norm.rvs(loc=0, scale=1, size=200)

# %%
data_normal
# Out:
# array([-0.50603276, -0.46555147, -0.29240902, -0.26568269,  0.14356075,
#         0.78468734,  0.28413397, -0.1540552 , -0.06715771,  1.42810057,
#        -0.91681081,  0.24088601,  0.34279447, -0.29259282,  1.36931214,
#         0.43599863,  1.09790339, -0.93370944, -1.05733601,  0.21764173,
#        -0.02214405,  0.61952871,  0.82918592,  1.16909216, -0.81894272,
#         0.67111081, -0.07857236, -0.41375347,  0.58057557, -0.29771249,
#         0.56206172,  1.11535781, -1.3645291 , -0.85928529,  1.99072637,
#         0.47859279, -0.32770001, -0.76914261, -1.53910109, -0.5938932 ,
#         0.39888282, -1.25629848,  0.57130602, -1.30693423, -0.64102745,
#        -1.22027503,  1.05534988, -1.35363494, -0.84343555,  0.75564817,
#         1.31557209, -1.79351667, -0.01223981, -0.60797219,  0.51255052,
#        -0.12475041,  2.08215728,  0.35012819,  0.02373049, -0.1803305 ,
#         0.49455792, -1.45360109, -0.91979973, -0.73156871,  0.99996827,
# ...

# %%
means_of_means = []
for experiment in range(1000):
    resampled= np.random.choice(data_normal, size=len(data_normal), replace=True)
    means_of_means.append(np.mean(resampled))

# %%
len(means_of_means)
# Out:
# 1000

# %%
np.mean(means_of_means)
# Out:
# -0.03789404263161271

# %%
lower_bound = np.quantile(means_of_means, 0.025)
upper_bound = np.quantile(means_of_means, 0.975)

# %%
print("95% CI of Population Means: ({}, {})".format(lower_bound, upper_bound))
# Out:
# 95% CI of Population Means: (-0.1726754619298266, 0.10507371690920891)

# %%
np.std(means_of_means)
# Out:
# 0.07251447165390644

# %%
lower_bound = np.mean(means_of_means) - np.std(means_of_means)*1.96
upper_bound = np.mean(means_of_means) - np.std(means_of_means)*1.96

print("95% CI of Population Means: ({}, {})".format(lower_bound, upper_bound))

# %% [markdown]
# # Central Limit Theorem
